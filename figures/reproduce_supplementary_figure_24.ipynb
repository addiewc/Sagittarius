# %% [markdown]
# # Python notebook to reproduce _Supplementary Figure 24_

# %%
import json
import os
import matplotlib.pyplot as plt

import plot_settings
import plot_utils

# %%
fig_dir = 'supplementary/figure_24/'
if not os.path.exists(fig_dir):
    os.makedirs(fig_dir)

# %% [markdown]
# # Code to reproduce Supplementary Figure 24a-j

# %% [markdown]
# Supplementary Fig. 24a

# %%
# %matplotlib inline

with open('results/TCGA/normalized_mutation_correlation/DNAH17_correlation.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] == ct_corrs[ct]]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    'Spearman correlation over time', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
plot_utils.format_ax(ax)
plt.title(r'$\itDNAH17}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_24a.pdf')
# Out:
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# Supplementary Fig. 24b

# %%
with open('results/TCGA/normalized_mutation_correlation/PREX1_correlation.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] == ct_corrs[ct]]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    'Spearman correlation over time', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
plot_utils.format_ax(ax)
plt.title(r'$\it{PREX1}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_24b.pdf')

# %% [markdown]
# Supplementary Fig. 11c

# %%
with open('results/TCGA/normalized_mutation_correlation/EGFLAM_correlation.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] == ct_corrs[ct]]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    'Spearman correlation over time', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
plot_utils.format_ax(ax)
plt.title(r'$\it{EGFLAM}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_11c.pdf')

# %% [markdown]
# Supplementary Fig. 11d

# %%
with open('results/TCGA/normalized_mutation_correlation/FAM47B_correlation.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] == ct_corrs[ct]]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    'Spearman correlation over time', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
plot_utils.format_ax(ax)
plt.title(r'$\it{FAM47B}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_11d.pdf')

# %% [markdown]
# Supplementary Fig. 11e

# %%
with open('results/TCGA/normalized_mutation_correlation/DSEL_correlation.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] == ct_corrs[ct]]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    'Spearman correlation over time', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
plot_utils.format_ax(ax)
plt.title(r'$\it{DSEL}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_11e.pdf')

# %% [markdown]
# Supplementary Fig. 11f

# %%
with open('results/TCGA/normalized_mutation_correlation/ARID2_correlation.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] == ct_corrs[ct]]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    'Spearman correlation over time', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
plot_utils.format_ax(ax)
plt.title(r'$\it{ARID2}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_11f.pdf')

# %% [markdown]
# Supplementary Fig. 11g

# %%
with open('results/TCGA/normalized_mutation_correlation/TRPM1_correlation.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] == ct_corrs[ct]]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    'Spearman correlation over time', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
plot_utils.format_ax(ax)
plt.title(r'$\it{TRPM1}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_11g.pdf')

# %% [markdown]
# Supplementary Fig. 11h

# %%
with open('results/TCGA/normalized_mutation_correlation/NLGN1_correlation.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] == ct_corrs[ct]]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    'Spearman correlation over time', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
plot_utils.format_ax(ax)
plt.title(r'$\it{NLGN1}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_11h.pdf')

# %% [markdown]
# Supplementary Fig. 11i

# %%
with open('results/TCGA/normalized_mutation_correlation/PTCH1_correlation.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] == ct_corrs[ct]]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    'Spearman correlation over time', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
plot_utils.format_ax(ax)
plt.title(r'$\it{PTCH1}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_11i.pdf')

# %% [markdown]
# Supplementary Fig. 11j

# %%
with open('results/TCGA/normalized_mutation_correlation/MYCBP2_correlation.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] == ct_corrs[ct]]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    'Spearman correlation over time', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
plot_utils.format_ax(ax)
plt.title(r'$\it{MYCBP2}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_11j.pdf')
