# %% [markdown]
# # Python notebook to reproduce _Supplementary Figure 26_

# %%
import json
import os
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

import plot_settings
import plot_utils

# %%
fig_dir = 'supplementary/figure_26/'
if not os.path.exists(fig_dir):
    os.makedirs(fig_dir)

# %% [markdown]
# # Code to reproduce Supplementary Figure 26a-j

# %% [markdown]
# Supplementary Fig. 26a

# %%
# %matplotlib inline

with open('results/TCGA/mutation_frequency/DNAH17_frequency.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] > 0]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    '% of patients with mutation', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0, decimals=0))
plot_utils.format_ax(ax)
plt.title(r'$\it{DNAH17}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_26a.pdf')
# Out:
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# Supplementary Fig. 26b

# %%
with open('results/TCGA/mutation_frequency/PREX1_frequency.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] > 0]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    '% of patients with mutation', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0, decimals=0))
plot_utils.format_ax(ax)
plt.title(r'$\it{PREX1}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_26b.pdf')

# %% [markdown]
# Supplementary Fig. 26c

# %%
with open('results/TCGA/mutation_frequency/EGFLAM_frequency.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] > 0]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    '% of patients with mutation', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0, decimals=0))
plot_utils.format_ax(ax)
plt.title(r'$\it{EGFLAM}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_26c.pdf')

# %% [markdown]
# Supplementary Fig. 26d

# %%
with open('results/TCGA/mutation_frequency/FAM47B_frequency.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] > 0]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    '% of patients with mutation', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0, decimals=0))
plot_utils.format_ax(ax)
plt.title(r'$\it{FAM47B}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_26d.pdf')

# %% [markdown]
# Supplementary Fig. 26e

# %%
with open('results/TCGA/mutation_frequency/DSEL_frequency.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] > 0]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    '% of patients with mutation', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0, decimals=0))
plot_utils.format_ax(ax)
plt.title(r'$\it{DSEL}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_26e.pdf')

# %% [markdown]
# Supplementary Fig. 26f

# %%
with open('results/TCGA/mutation_frequency/ARID2_frequency.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] > 0]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    '% of patients with mutation', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0, decimals=0))
plot_utils.format_ax(ax)
plt.title(r'$\it{ARID2}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_26f.pdf')

# %% [markdown]
# Supplementary Fig. 26g

# %%
with open('results/TCGA/mutation_frequency/TRPM1_frequency.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] > 0]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    '% of patients with mutation', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0, decimals=0))
plot_utils.format_ax(ax)
plt.title(r'$\it{TRPM1}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_26g.pdf')

# %% [markdown]
# Supplementary Fig. 26h

# %%
with open('results/TCGA/mutation_frequency/NLGN1_frequency.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] > 0]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    '% of patients with mutation', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0, decimals=0))
plot_utils.format_ax(ax)
plt.title(r'$\it{NLGN1}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_26h.pdf')

# %% [markdown]
# Supplementary Fig. 26i

# %%
with open('results/TCGA/mutation_frequency/PTCH1_frequency.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] > 0]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    '% of patients with mutation', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0, decimals=0))
plot_utils.format_ax(ax)
plt.title(r'$\it{PTCH1}$')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_26i.pdf')

# %% [markdown]
# Supplementary Fig. 26j

# %%
with open('results/TCGA/mutation_frequency/MYCBP2_frequency.txt', 'r') as f:
    ct_corrs = json.load(f)
    
ax = plot_settings.get_square_axis()

cts_to_show = [ct for ct in ct_corrs.keys() if ct_corrs[ct] > 0]
cts_to_show = sorted(cts_to_show, key=lambda ct: ct_corrs[ct])

plot_utils.horizontal_bar_plot(
    ax, [ct_corrs[ct] for ct in cts_to_show], cts_to_show, 
    '% of patients with mutation', '', xscale='linear', yscale='linear',
    min_val=0, invert_axes=False, color=plot_settings.get_base_color(),
    edge_color=plot_settings.get_model_colors('cvae'))
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0, decimals=0))
plot_utils.format_ax(ax)
plt.title('MYCBP2')
plt.tight_layout()
plt.savefig(fig_dir + 'figure_26j.pdf')
